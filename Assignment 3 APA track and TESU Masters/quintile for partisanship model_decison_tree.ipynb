# %%
import pandas as pd

# %%
df_voter_ID_modelscore_decison_tree_df = pd.read_csv('df_voter_ID_modelscore_decison_tree.csv')

# %%
df_voter_ID_modelscore_decison_tree_df.head()
# Out:
#    VOTER_ID_100  y_100_S
# 0        173833        1
# 1        219001        0
# 2        437161        0
# 3        343581        1
# 4        620443        1

# %%
scores = df_voter_ID_modelscore_decison_tree_df["y_100_S"]

# %%
print("Scores as loaded into the pandas.Series instance:");

print(scores);
# Out:
# Scores as loaded into the pandas.Series instance:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     1
#      ..
# 95    1
# 96    1
# 97    0
# 98    1
# 99    1
# Name: y_100_S, Length: 100, dtype: int64

# %%
print("First Quartile:%.2f"%scores.quantile(.25));

print("Second Quartile:%.2f"%scores.quantile(.5));

print("Third Quartile:%.2f"%scores.quantile(.75));

print("100th Percentile:%.2f"%scores.quantile(1));

print("1st Percentile:%.2f"%scores.quantile(.1));
# Out:
# First Quartile:0.00
# Second Quartile:1.00
# Third Quartile:1.00
# 100th Percentile:1.00
# 1st Percentile:0.00

# %% [markdown]
# ![image.png](attachment:image.png)
